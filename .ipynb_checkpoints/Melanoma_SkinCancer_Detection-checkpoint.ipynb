# %% [markdown]
# ## Problem statement:
# Build a CNN based model which can accurately detect melanoma. Melanoma is a type of cancer that can be deadly if not detected early. It accounts for 75% of skin cancer deaths. A solution which can evaluate images and alert the dermatologists about the presence of melanoma has the potential to reduce a lot of manual effort needed in diagnosis.

# %%
# #mount google drive
# from google.colab import drive
# drive.mount('/content/gdrive')

# %%
#unzip the dataset
# !unzip "/content/gdrive/MyDrive/SkinCancerDataset.zip" > /dev/null

# %%
#import the required libraries
import pathlib
import os

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import PIL

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint,EarlyStopping

from tensorflow.keras.utils import image_dataset_from_directory
from tensorflow.keras.utils import load_img
from tensorflow.keras.models import Sequential
from tensorflow.keras import layers
from sklearn.utils.class_weight import compute_class_weight

# %%
# Defining the path for train and test images
data_dir_train = pathlib.Path("C:/Users/Anand Mall/Downloads/My/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train")
data_dir_test = pathlib.Path("C:/Users/Anand Mall/Downloads/My/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test")

# %%
# Count the number of image in Train and Test directory

#Train Image count
image_count_train = len(list(data_dir_train.glob('*/*.jpg')))
print(image_count_train)

#Test Image count
image_count_test = len(list(data_dir_test.glob('*/*.jpg')))
print(image_count_test)
# Out:
# 2239
# 118

# %% [markdown]
# **Data Visualization**

# %%
#Visualize one instance of all the class present in the dataset.

#image_dataset_from_directory() will return a tf.data.Dataset that yields batches of images from the subdirectories.
#label_mode is categorial, the labels are a float32 tensor of shape (batch_size, num_classes), representing a one-hot encoding of the class index.
image_dataset = tf.keras.utils.image_dataset_from_directory(data_dir_train, 
                                                            batch_size=32, 
                                                            image_size=(180, 180), 
                                                            label_mode='categorical', 
                                                            seed=123
)

#all the classes of Skin Cancer
class_names = image_dataset.class_names

#Dictionary to store the path of image as per the class
files_path_dict = {}

for c in class_names:
    files_path_dict[c] = list(map(lambda x:str(data_dir_train)+'/'+c+'/'+x,os.listdir(str(data_dir_train)+'/'+c)))
    
#Visualize image 
plt.figure(figsize=(15,15))
index = 0
for c in class_names:
    path_list = files_path_dict[c][:1]
    index += 1
    plt.subplot(3,3,index)
    plt.imshow(load_img(path_list[0],target_size=(180,180)))
    plt.title(c)
    plt.axis("off")
# Out:
# Found 2239 files belonging to 9 classes.

# %% [markdown]
# **Visualize distribution of classes in the training dataset.**

# %%
def class_distribution_count(directory):
    
    #count number of image in each classes
    count= []
    for path in pathlib.Path(directory).iterdir():
        if path.is_dir():
            count.append(len([name for name in os.listdir(path)
                               if os.path.isfile(os.path.join(path, name))]))
    
    #name of the classes
    sub_directory = [name for name in os.listdir(directory)
                    if os.path.isdir(os.path.join(directory, name))]
    
    #return dataframe with image count and class.
    return pd.DataFrame(list(zip(sub_directory,count)),columns =['Class', 'No. of Image'])

df = class_distribution_count(data_dir_train)
df
# Out:
#                         Class  No. of Image
# 0           actinic keratosis           114
# 1        basal cell carcinoma           376
# 2              dermatofibroma            95
# 3                    melanoma           438
# 4                       nevus           357
# 5  pigmented benign keratosis           462
# 6        seborrheic keratosis            77
# 7     squamous cell carcinoma           181
# 8             vascular lesion           139

# %%
#Visualize the Number of image in each class.
import seaborn as sns
plt.figure(figsize=(10, 5))
sns.barplot(x="No. of Image", y="Class", data=df,
            hue="Class")
# Out:
# <Axes: xlabel='No. of Image', ylabel='Class'>

# %% [markdown]
# There is a class imbalance to solve this using a python package  Augmentor (https://augmentor.readthedocs.io/en/master/) to add more samples across all classes so that none of the classes have very few samples.

# %%
#install Augmentor
# !pip install Augmentor

# %%
import Augmentor

path_to_training_dataset = "C:/Users/Anand Mall/Downloads/My/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/"

import Augmentor
for i in class_names:
    p = Augmentor.Pipeline(path_to_training_dataset + i)
    p.rotate(probability=0.7, max_left_rotation=10, max_right_rotation=10)
    p.sample(500)  #Adding 500 samples per class to make sure that none of the classes are sparse
# Out:
# Initialised with 114 image(s) found.
# Output directory set to C:/Users/Anand Mall/Downloads/My/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis\output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x11536BD7C70>: 100%|█| 500/500 [00:08<00:
# Initialised with 376 image(s) found.
# Output directory set to C:/Users/Anand Mall/Downloads/My/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma\output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x11536C2EAD0>: 100%|█| 500/500 [00:07<00:00, 63.89 Samples/
# Initialised with 95 image(s) found.
# Output directory set to C:/Users/Anand Mall/Downloads/My/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/dermatofibroma\output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x11536C591E0>: 100%|█| 500/500 [00:05<00:00, 90.75 Samples/
# Initialised with 438 image(s) found.
# Output directory set to C:/Users/Anand Mall/Downloads/My/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/melanoma\output.
# Processing <PIL.Image.Image image mode=RGB size=767x576 at 0x11324564820>: 100%|█| 500/500 [00:24<00:00, 20.16 Samples/
# Initialised with 357 image(s) found.
# Output directory set to C:/Users/Anand Mall/Downloads/My/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus\output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x1132453EB30>: 100%|█| 500/500 [00:25<00:00, 19.54 Samples/
# Initialised with 462 image(s) found.
# Output directory set to C:/Users/Anand Mall/Downloads/My/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/pigmented benign keratosis\output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x11536C175E0>: 100%|█| 500/500 [00:04<00:00, 102.28 Samples
# Initialised with 77 image(s) found.
# Output directory set to C:/Users/Anand Mall/Downloads/My/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/seborrheic keratosis\output.
# Processing <PIL.Image.Image image mode=RGB size=1024x768 at 0x11302850EB0>: 100%|█| 500/500 [00:11<00:00, 42.00 Samples
# Initialised with 181 image(s) found.
# Output directory set to C:/Users/Anand Mall/Downloads/My/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/squamous cell carcinoma\output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x1152D8A6A40>: 100%|█| 500/500 [00:04<00:
# Initialised with 139 image(s) found.
# Output directory set to C:/Users/Anand Mall/Downloads/My/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion\output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x1152D94C0D0>: 100%|█| 500/500 [00:05<00:00, 95.96 Samples/

# %%
#Count total number of image generated by Augmentor.
image_count_train = len(list(data_dir_train.glob('*/output/*.jpg')))
print(image_count_train)
# Out:
# 4500

# %% [markdown]
# **Model Building**

# %% [markdown]
# ## Train dataset

# %%
train_ds = tf.keras.preprocessing.image_dataset_from_directory(data_dir_train, batch_size=32,
                                                               image_size=(180,180), label_mode='categorical',
                                                               seed=123,subset="training",
                                                               validation_split=0.2)
# Out:
# Found 6739 files belonging to 9 classes.
# Using 5392 files for training.

# %% [markdown]
# # Validation dataset

# %%
val_ds =tf.keras.preprocessing.image_dataset_from_directory(data_dir_train,batch_size=32,
                                                            image_size=(180,180), label_mode='categorical',
                                                            seed=123,subset="validation",
                                                            validation_split=0.2)
# Out:
# Found 6739 files belonging to 9 classes.
# Using 1347 files for validation.

# %%
#tf.data.experimental.AUTOTUNE defines appropriate number of processes that are free for working.

#`Dataset.cache()` keeps the images in memory after they're loaded off disk during the first epoch.

#`Dataset.prefetch()` overlaps data preprocessing and model execution while training.


AUTOTUNE = tf.data.experimental.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
#CNN Model Architecture

#Sequential allows you to create models layer-by-layer  
model = Sequential()

model.add(layers.experimental.preprocessing.Rescaling(1./255,input_shape=(180,180,3)))   #Rescaling Layer

#First Convulation layer
model.add(layers.Conv2D(32,kernel_size=(3,3),activation='relu'))
model.add(layers.MaxPool2D(pool_size=(2,2)))

#Second Convulation Layer
model.add(layers.Conv2D(64,kernel_size=(3,3),activation='relu'))
model.add(layers.MaxPool2D(pool_size=(2,2)))

#Third Convulation Layer
model.add(layers.Conv2D(128,kernel_size=(3,3),activation='relu'))
model.add(layers.MaxPool2D(pool_size=(2,2)))

#Dropout layer with 50% Fraction of the input units to drop.
model.add(layers.Dropout(0.5))

#Flatten Layer
##Keras.layers.flatten function flattens the multi-dimensional input tensors into a single dimension.
model.add(layers.Flatten())

#Dense Layer
model.add(layers.Dense(128,activation='relu')) #dense

#Dropout layer with 25% Fraction of the input units to drop.
model.add(layers.Dropout(0.25))

#Dense Layer with softmax activation function.
#Softmax is an activation function that scales numbers/logits into probabilities.
model.add(layers.Dense(len(class_names),activation='softmax'))

model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_3 (Rescaling)     (None, 180, 180, 3)       0
#
#  conv2d_9 (Conv2D)           (None, 178, 178, 32)      896
#
#  max_pooling2d_9 (MaxPooling  (None, 89, 89, 32)       0
#  2D)
#
#  conv2d_10 (Conv2D)          (None, 87, 87, 64)        18496
#
#  max_pooling2d_10 (MaxPoolin  (None, 43, 43, 64)       0
#  g2D)
#
#  conv2d_11 (Conv2D)          (None, 41, 41, 128)       73856
#
#  max_pooling2d_11 (MaxPoolin  (None, 20, 20, 128)      0
#  g2D)
#
#  dropout_6 (Dropout)         (None, 20, 20, 128)       0
#
#  flatten_3 (Flatten)         (None, 51200)             0
#
#  dense_6 (Dense)             (None, 128)               6553728
#
#  dropout_7 (Dropout)         (None, 128)               0
#
#  dense_7 (Dense)             (None, 9)                 1161
#
# =================================================================
# Total params: 6,648,137
# Trainable params: 6,648,137
# Non-trainable params: 0
# _________________________________________________________________

# %%
# # vizualizing the model 
# from tensorflow.keras.utils import plot_model
# plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %%
#Compile the Model

#Adam optimization: is a stochastic gradient descent method that is based on adaptive estimation of first-order and second-order moments.
#categorical_crossentropy: Used as a loss function for multi-class classification model where there are two or more output labels.

model.compile(optimizer="Adam",loss="categorical_crossentropy",metrics=["accuracy"])

#ModelCheckpoint callback is used in conjunction with training using model.fit() to save a model or weights (in a checkpoint file) at some interval,
#so the model or weights can be loaded later to continue the training from the state saved.
checkpoint = ModelCheckpoint("model.h5",monitor="val_accuracy",save_best_only=True,mode="auto",verbose=1)

#Stop training when a monitored metric has stopped improving.
earlystop = EarlyStopping(monitor="val_accuracy",patience=5,mode="auto",verbose=1)

# %%
# Train the model
epochs = 25
history = model.fit(train_ds, validation_data=val_ds, epochs=epochs,callbacks=[checkpoint,earlystop])
# Out:
# Epoch 1/25
# 169/169 [==============================] - ETA: 0s - loss: 2.0052 - accuracy: 0.2428
# Epoch 1: val_accuracy improved from -inf to 0.37788, saving model to model.h5
# 169/169 [==============================] - 127s 627ms/step - loss: 2.0052 - accuracy: 0.2428 - val_loss: 1.6584 - val_accuracy: 0.3779
# Epoch 2/25
# 169/169 [==============================] - ETA: 0s - loss: 1.5382 - accuracy: 0.4177
# Epoch 2: val_accuracy improved from 0.37788 to 0.45434, saving model to model.h5
# 169/169 [==============================] - 150s 885ms/step - loss: 1.5382 - accuracy: 0.4177 - val_loss: 1.4267 - val_accuracy: 0.4543
# Epoch 3/25
# 169/169 [==============================] - ETA: 0s - loss: 1.4129 - accuracy: 0.4653
# Epoch 3: val_accuracy improved from 0.45434 to 0.51819, saving model to model.h5
# 169/169 [==============================] - 176s 1s/step - loss: 1.4129 - accuracy: 0.4653 - val_loss: 1.2563 - val_accuracy: 0.5182
# Epoch 4/25
# 169/169 [==============================] - ETA: 0s - loss: 1.2365 - accuracy: 0.5356
# Epoch 4: val_accuracy improved from 0.51819 to 0.58575, saving model to model.h5
# 169/169 [==============================] - 160s 945ms/step - loss: 1.2365 - accuracy: 0.5356 - val_loss: 1.0924 - val_accuracy: 0.5857
# Epoch 5/25
# 169/169 [==============================] - ETA: 0s - loss: 1.0958 - accuracy: 0.5946
# Epoch 5: val_accuracy improved from 0.58575 to 0.65108, saving model to model.h5
# 169/169 [==============================] - 185s 1s/step - loss: 1.0958 - accuracy: 0.5946 - val_loss: 0.9620 - val_accuracy: 0.6511
# Epoch 6/25
# 169/169 [==============================] - ETA: 0s - loss: 0.9575 - accuracy: 0.6439
# Epoch 6: val_accuracy improved from 0.65108 to 0.69785, saving model to model.h5
# 169/169 [==============================] - 166s 983ms/step - loss: 0.9575 - accuracy: 0.6439 - val_loss: 0.8639 - val_accuracy: 0.6978
# Epoch 7/25
# 169/169 [==============================] - ETA: 0s - loss: 0.8221 - accuracy: 0.6931
# Epoch 7: val_accuracy improved from 0.69785 to 0.70973, saving model to model.h5
# 169/169 [==============================] - 155s 917ms/step - loss: 0.8221 - accuracy: 0.6931 - val_loss: 0.8563 - val_accuracy: 0.7097
# Epoch 8/25
# 169/169 [==============================] - ETA: 0s - loss: 0.7404 - accuracy: 0.7281
# Epoch 8: val_accuracy improved from 0.70973 to 0.74536, saving model to model.h5
# 169/169 [==============================] - 153s 907ms/step - loss: 0.7404 - accuracy: 0.7281 - val_loss: 0.7391 - val_accuracy: 0.7454
# Epoch 9/25
# 169/169 [==============================] - ETA: 0s - loss: 0.6331 - accuracy: 0.7667
# Epoch 9: val_accuracy did not improve from 0.74536
# 169/169 [==============================] - 156s 924ms/step - loss: 0.6331 - accuracy: 0.7667 - val_loss: 0.7560 - val_accuracy: 0.7268
# Epoch 10/25
# 169/169 [==============================] - ETA: 0s - loss: 0.5902 - accuracy: 0.7838
# Epoch 10: val_accuracy improved from 0.74536 to 0.75056, saving model to model.h5
# 169/169 [==============================] - 154s 913ms/step - loss: 0.5902 - accuracy: 0.7838 - val_loss: 0.7168 - val_accuracy: 0.7506
# Epoch 11/25
# 169/169 [==============================] - ETA: 0s - loss: 0.5421 - accuracy: 0.8038
# Epoch 11: val_accuracy improved from 0.75056 to 0.75130, saving model to model.h5
# 169/169 [==============================] - 151s 895ms/step - loss: 0.5421 - accuracy: 0.8038 - val_loss: 0.6711 - val_accuracy: 0.7513
# Epoch 12/25
# 169/169 [==============================] - ETA: 0s - loss: 0.4502 - accuracy: 0.8344
# Epoch 12: val_accuracy improved from 0.75130 to 0.77134, saving model to model.h5
# 169/169 [==============================] - 152s 899ms/step - loss: 0.4502 - accuracy: 0.8344 - val_loss: 0.6545 - val_accuracy: 0.7713
# Epoch 13/25
# 169/169 [==============================] - ETA: 0s - loss: 0.4318 - accuracy: 0.8394
# Epoch 13: val_accuracy improved from 0.77134 to 0.79733, saving model to model.h5
# 169/169 [==============================] - 168s 994ms/step - loss: 0.4318 - accuracy: 0.8394 - val_loss: 0.5848 - val_accuracy: 0.7973
# Epoch 14/25
# 169/169 [==============================] - ETA: 0s - loss: 0.4016 - accuracy: 0.8544
# Epoch 14: val_accuracy did not improve from 0.79733
# 169/169 [==============================] - 151s 894ms/step - loss: 0.4016 - accuracy: 0.8544 - val_loss: 0.6379 - val_accuracy: 0.7936
# Epoch 15/25
# 169/169 [==============================] - ETA: 0s - loss: 0.4069 - accuracy: 0.8516
# Epoch 15: val_accuracy did not improve from 0.79733
# 169/169 [==============================] - 156s 921ms/step - loss: 0.4069 - accuracy: 0.8516 - val_loss: 0.6762 - val_accuracy: 0.7884
# Epoch 16/25
# 169/169 [==============================] - ETA: 0s - loss: 0.3247 - accuracy: 0.8793
# Epoch 16: val_accuracy improved from 0.79733 to 0.81366, saving model to model.h5
# 169/169 [==============================] - 159s 942ms/step - loss: 0.3247 - accuracy: 0.8793 - val_loss: 0.6186 - val_accuracy: 0.8137
# Epoch 17/25
# 169/169 [==============================] - ETA: 0s - loss: 0.3413 - accuracy: 0.8731
# Epoch 17: val_accuracy did not improve from 0.81366
# 169/169 [==============================] - 152s 902ms/step - loss: 0.3413 - accuracy: 0.8731 - val_loss: 0.8431 - val_accuracy: 0.7669
# Epoch 18/25
# 169/169 [==============================] - ETA: 0s - loss: 0.3306 - accuracy: 0.8767
# Epoch 18: val_accuracy improved from 0.81366 to 0.83519, saving model to model.h5
# 169/169 [==============================] - 147s 870ms/step - loss: 0.3306 - accuracy: 0.8767 - val_loss: 0.5913 - val_accuracy: 0.8352
# Epoch 19/25
# 169/169 [==============================] - ETA: 0s - loss: 0.2807 - accuracy: 0.8961
# Epoch 19: val_accuracy did not improve from 0.83519
# 169/169 [==============================] - 152s 899ms/step - loss: 0.2807 - accuracy: 0.8961 - val_loss: 0.6034 - val_accuracy: 0.8218
# Epoch 20/25
# 169/169 [==============================] - ETA: 0s - loss: 0.2650 - accuracy: 0.8999
# Epoch 20: val_accuracy did not improve from 0.83519
# 169/169 [==============================] - 151s 895ms/step - loss: 0.2650 - accuracy: 0.8999 - val_loss: 0.5996 - val_accuracy: 0.8270
# Epoch 21/25
# 169/169 [==============================] - ETA: 0s - loss: 0.2668 - accuracy: 0.8989
# Epoch 21: val_accuracy did not improve from 0.83519
# 169/169 [==============================] - 150s 887ms/step - loss: 0.2668 - accuracy: 0.8989 - val_loss: 0.6537 - val_accuracy: 0.8226
# Epoch 22/25
# 169/169 [==============================] - ETA: 0s - loss: 0.2762 - accuracy: 0.9008
# Epoch 22: val_accuracy did not improve from 0.83519
# 169/169 [==============================] - 151s 896ms/step - loss: 0.2762 - accuracy: 0.9008 - val_loss: 0.7724 - val_accuracy: 0.7832
# Epoch 23/25
# 169/169 [==============================] - ETA: 0s - loss: 0.2504 - accuracy: 0.9050
# Epoch 23: val_accuracy did not improve from 0.83519
# 169/169 [==============================] - 111s 654ms/step - loss: 0.2504 - accuracy: 0.9050 - val_loss: 0.6656 - val_accuracy: 0.8151
# Epoch 23: early stopping

# %% [markdown]
# ## Test Dataset

# %%
test_ds = tf.keras.preprocessing.image_dataset_from_directory(data_dir_test,
                                                                batch_size=32,
                                                                image_size=(180, 180),
                                                                label_mode='categorical',
                                                                shuffle=False)
# Out:
# Found 115 files belonging to 9 classes.

# %% [markdown]
# ## Check Model Accuracy on the Validation Dataset

# %%
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc

# %%
# Extract true labels
y_true = np.concatenate([y for _, y in test_ds], axis=0)
y_true_classes = np.argmax(y_true, axis=1)

# Predict probabilities and classes
y_pred_prob = model.predict(test_ds)
y_pred_classes = np.argmax(y_pred_prob, axis=1)

# Classification report
report = classification_report(y_true_classes, y_pred_classes, target_names=test_ds.class_names)
print("Classification Report:\n", report)
# Out:
# 4/4 [==============================] - 1s 150ms/step
# Classification Report:
#                              precision    recall  f1-score   support
#
#          actinic keratosis       0.82      0.75      0.78        12
#       basal cell carcinoma       0.85      0.79      0.81        14
#             dermatofibroma       0.71      0.91      0.80        11
#                   melanoma       0.80      0.86      0.83        14
#                      nevus       0.71      0.92      0.80        13
# pigmented benign keratosis       0.85      0.69      0.76        16
#       seborrheic keratosis       0.80      0.80      0.80        10
#    squamous cell carcinoma       1.00      0.75      0.86        12
#            vascular lesion       0.92      0.92      0.92        13
#
#                   accuracy                           0.82       115
#                  macro avg       0.83      0.82      0.82       115
#               weighted avg       0.83      0.82      0.82       115

# %% [markdown]
# ## Compute the confusion matrix

# %%
cm = confusion_matrix(y_true_classes, y_pred_classes)
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=test_ds.class_names, yticklabels=test_ds.class_names)
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# %%
cm
# Out:
# array([[ 1,  1,  0,  1, 10,  3,  0,  0,  0],
#        [ 1,  6,  1,  2,  0,  4,  0,  2,  0],
#        [ 0,  6,  1,  2,  5,  1,  0,  1,  0],
#        [ 0,  0,  0,  1, 11,  4,  0,  0,  0],
#        [ 0,  0,  0,  0, 16,  0,  0,  0,  0],
#        [ 0,  1,  2,  0,  1, 11,  1,  0,  0],
#        [ 0,  1,  0,  2,  0,  0,  0,  0,  0],
#        [ 0,  2,  2,  5,  2,  2,  0,  2,  1],
#        [ 0,  1,  0,  0,  0,  0,  0,  0,  2]], dtype=int64)

# %%
# Plot the training curves

epochs_range = range(earlystop.stopped_epoch+1)

plt.figure(figsize=(15, 10))
plt.subplot(1, 2, 1)

#Plot Model Accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel(epochs_range)
plt.legend(['train', 'val'], loc='upper left')

#Plot Model Loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel(epochs_range)
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %% [markdown]
# ## Model Prediction

# %%
from glob import glob
plt.figure(figsize=(9, 9))
index = 0
for c in class_names:
    if c in files_path_dict: 
        path_list = files_path_dict[c][:1]
        index += 1
        plt.subplot(3, 3, index)
        
        # Load image
        img = load_img(path_list[0], target_size=(180, 180))
        plt.imshow(img)
        plt.axis("off")
        
        # Prepare image for prediction
        img_array = np.expand_dims(img, axis=0)
        pred = model.predict(img_array)
        pred_class_idx = np.argmax(pred)
        pred_class = class_names[pred_class_idx]
        
        # Set title with actual and predicted labels
        title = f"Actual: {c}\nPred: {pred_class}"
        if c == pred_class:
            plt.title(title, color='green', fontsize=12, pad=10)
        else:
            plt.title(title, color='red', fontsize=12, pad=10)

plt.tight_layout()
plt.show()
# Out:
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 52ms/step

# %% [markdown]
# ## Sensitivity Specificity

# %%
def calculate_metrics(cm, class_idx):
    TP = cm[class_idx, class_idx]
    FN = cm[class_idx, :].sum() - TP
    FP = cm[:, class_idx].sum() - TP
    TN = cm.sum() - (TP + FN + FP)
    sensitivity = TP / (TP + FN) if (TP + FN) > 0 else 0
    specificity = TN / (TN + FP) if (TN + FP) > 0 else 0
    return sensitivity, specificity

for i, class_name in enumerate(test_ds.class_names):
    sensitivity, specificity = calculate_metrics(cm, i)
    print(f"{class_name}:      Sensitivity={sensitivity:.3f},    Specificity={specificity:.3f}")
# Out:
# actinic keratosis:      Sensitivity=0.750,    Specificity=0.981
# basal cell carcinoma:      Sensitivity=0.786,    Specificity=0.980
# dermatofibroma:      Sensitivity=0.909,    Specificity=0.962
# melanoma:      Sensitivity=0.857,    Specificity=0.970
# nevus:      Sensitivity=0.923,    Specificity=0.951
# pigmented benign keratosis:      Sensitivity=0.688,    Specificity=0.980
# seborrheic keratosis:      Sensitivity=0.800,    Specificity=0.981
# squamous cell carcinoma:      Sensitivity=0.750,    Specificity=1.000
# vascular lesion:      Sensitivity=0.923,    Specificity=0.990

# %% [markdown]
# ## ROC Curve and AUC

# %%
from itertools import cycle
fpr = dict()
tpr = dict()
roc_auc = dict()
n_classes = len(test_ds.class_names)

for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_true[:, i], y_pred_prob[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

plt.figure(figsize=(10, 8))
colors = cycle(['blue', 'red', 'green', 'yellow', 'purple', 'orange', 'pink', 'brown', 'gray'])
for i, color in zip(range(n_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=2, label=f'{test_ds.class_names[i]} (AUC = {roc_auc[i]:.2f})')

plt.plot([0, 1], [0, 1], 'k--', lw=2)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve (One-vs-Rest)')
plt.legend(loc='lower right')
plt.show()

fpr["micro"], tpr["micro"], _ = roc_curve(y_true.ravel(), y_pred_prob.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])
print(f"Micro-average AUC: {roc_auc['micro']:.3f}")
# Out:
# Micro-average AUC: 0.935

# %%
from sklearn.metrics import accuracy_score

# %%
print("Accuracy Score")
accuracy=accuracy_score(y_true_classes,y_pred_classes)
print(accuracy)
# Out:
# Accuracy Score
# 0.8173913043478261
